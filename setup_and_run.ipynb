# %% [markdown]
# # PyWarlight RL Agent Setup and Execution
#
# This notebook provides a complete setup and execution environment for running the PyWarlight reinforcement learning agents. It will install all dependencies and run a simulation with the specified configuration.
#
# ## Overview
# - **Option 1**: Clone the project directly from GitHub (recommended for Colab)
# - **Option 2**: Use local files (for local Jupyter environments)
# - Installs all required Python packages from requirements.txt
# - Sets up the environment for running RL agent simulations
# - Executes the command: `python main.py Attila.1 RLGNNAgent.2 -sim 1 -map World -config debug`

# %% [markdown]
# ## 0. Setup Project Files
#
# Choose your setup method:
# - **Method A**: Clone from GitHub (recommended for Google Colab)
# - **Method B**: Use local files (for local Jupyter environments)

# %%
import os
import sys
import subprocess

# Configuration
USE_GITHUB = True  # Set to False if you want to use local files instead
GITHUB_USERNAME = "DonnyWhoLovedBowling"
REPO_NAME = "pyWarlight"
GITHUB_URL = f"https://github.com/{GITHUB_USERNAME}/{REPO_NAME}.git"

print("🚀 PyWarlight RL Agent Setup")
print("=" * 50)

if USE_GITHUB:
    print(f"📂 Method A: Cloning from GitHub repository")
    print(f"Repository: {GITHUB_URL}")

    # Check if git is available
    try:
        subprocess.run(['git', '--version'], check=True, capture_output=True)
        print("✅ Git is available")
    except (subprocess.CalledProcessError, FileNotFoundError):
        print("❌ Git not found. Installing git...")
        # For Google Colab
        try:
            subprocess.run(['apt-get', 'update', '-qq'], check=True)
            subprocess.run(['apt-get', 'install', '-y', 'git'], check=True)
            print("✅ Git installed successfully")
        except:
            print("❌ Could not install git. Please install manually or use local files.")
            USE_GITHUB = False

    if USE_GITHUB:
        # Clone the repository
        if os.path.exists(REPO_NAME):
            print(f"📁 Directory {REPO_NAME} already exists. Updating...")
            os.chdir(REPO_NAME)
            result = subprocess.run(['git', 'pull'], capture_output=True, text=True)
            if result.returncode == 0:
                print("✅ Repository updated successfully")
            else:
                print(f"⚠️ Update failed: {result.stderr}")
                print("Continuing with existing files...")
        else:
            print(f"📥 Cloning repository...")
            result = subprocess.run(['git', 'clone', GITHUB_URL], capture_output=True, text=True)
            if result.returncode == 0:
                print("✅ Repository cloned successfully")
                os.chdir(REPO_NAME)
            else:
                print(f"❌ Clone failed: {result.stderr}")
                print("Falling back to local files method...")
                USE_GITHUB = False

if not USE_GITHUB:
    print(f"📂 Method B: Using local files")
    print("Make sure you have the pyWarlight project files in the current directory.")

    # For Google Colab, provide file upload option
    try:
        from google.colab import files
        import zipfile

        print("\n📤 Google Colab detected. You can upload a ZIP file of your project:")
        print("1. Create a ZIP file of your pyWarlight project")
        print("2. Run the next cell to upload it")
        print("\nAlternatively, you can skip upload if files are already present.")

        # Check if we should prompt for upload
        if not os.path.exists('main.py'):
            print("\n⬆️ Upload your project ZIP file:")
            uploaded = files.upload()

            # Extract ZIP file
            for filename in uploaded.keys():
                if filename.endswith('.zip'):
                    print(f"📦 Extracting {filename}...")
                    with zipfile.ZipFile(filename, 'r') as zip_ref:
                        zip_ref.extractall('.')

                    # Check if extracted into a subdirectory
                    if os.path.exists('pyWarlight'):
                        os.chdir('pyWarlight')
                        print("📁 Moved to pyWarlight directory")

                    print("✅ Files extracted successfully")
                    break
        else:
            print("✅ Project files found in current directory")

    except ImportError:
        # Not in Colab
        print("💻 Local Jupyter environment detected")
        if not os.path.exists('main.py'):
            print("❌ main.py not found in current directory")
            print("Please ensure you're running this notebook from the pyWarlight project directory.")

print(f"\n📍 Current working directory: {os.getcwd()}")
print(f"📄 Files in directory: {[f for f in os.listdir('.') if os.path.isfile(f)][:10]}")
print(f"📁 Subdirectories: {[d for d in os.listdir('.') if os.path.isdir(d)][:10]}")
# Out:
# 🚀 PyWarlight RL Agent Setup
# ==================================================
# 📂 Method A: Cloning from GitHub repository
# Repository: https://github.com/DonnyWhoLovedBowling/pyWarlight.git
# ✅ Git is available
# 📁 Directory pyWarlight already exists. Updating...
# ✅ Repository updated successfully
#
# 📍 Current working directory: /content/pyWarlight
# 📄 Files in directory: ['comprehensive_debug_test.py', 'debug_batch_consistency.py', 'oceania.txt', 'debug_edge_matching.py', 'test_models.py', 'simple_log_prob_test.py', 'final_stability_test.py', 'reduced_army_usage_example.py', 'main.py', 'analyze_tensorboard.py']
# 📁 Subdirectories: ['pyWarlight', 'tests', '.github', 'src', '.vscode', '.idea', 'res', 'analysis', '.git']

# %% [markdown]
# ## 1. Install System Requirements
#
# Check the system environment and install any necessary system-level dependencies.

# %%
import sys
import platform

print("🖥️ System Information:")
print(f"Python version: {sys.version}")
print(f"Platform: {platform.platform()}")
print(f"Current working directory: {os.getcwd()}")
print(f"Python executable: {sys.executable}")

# Check if we're in Google Colab
try:
    import google.colab
    IN_COLAB = True
    print("🌐 Running in Google Colab")

    # Enable GPU if available
    import torch
    if torch.cuda.is_available():
        print(f"🚀 CUDA available: {torch.cuda.get_device_name(0)}")
        os.environ['CUDA_VISIBLE_DEVICES'] = '0'
    else:
        print("💻 CUDA not available, using CPU")

except ImportError:
    IN_COLAB = False
    print("💻 Running in local environment")

# Install system dependencies for Colab
if IN_COLAB:
    print("\n📦 Installing system dependencies for Colab...")
    try:
        subprocess.run(['apt-get', 'update', '-qq'], check=True)
        subprocess.run(['apt-get', 'install', '-y', 'build-essential'], check=True)
        print("✅ System dependencies installed")
    except Exception as e:
        print(f"⚠️ System dependency installation failed: {e}")
# Out:
# 🖥️ System Information:
# Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# Platform: Linux-6.1.123+-x86_64-with-glibc2.35
# Current working directory: /content/pyWarlight
# Python executable: /usr/bin/python3
# 🌐 Running in Google Colab
# 🚀 CUDA available: Tesla T4
#
# 📦 Installing system dependencies for Colab...
# ✅ System dependencies installed

# %% [markdown]
# ## 2. Install Python Dependencies
#
# Install all required Python packages, with optimizations for different environments.

# %%
print("📦 Installing Python dependencies...")

# For Google Colab, install PyTorch with CUDA support first
if IN_COLAB:
    print("🔥 Installing PyTorch with CUDA support for Colab...")

    # Install PyTorch with CUDA
    torch_result = subprocess.run([
        sys.executable, '-m', 'pip', 'install',
        'torch', 'torchvision', 'torchaudio',
        '--index-url', 'https://download.pytorch.org/whl/cu118'
    ], capture_output=True, text=True)

    if torch_result.returncode == 0:
        print("✅ PyTorch with CUDA installed successfully")
    else:
        print(f"⚠️ PyTorch installation warning: {torch_result.stderr}")

    # Install PyTorch Geometric with CUDA support
    print("📊 Installing PyTorch Geometric with CUDA support...")
    pyg_packages = [
        'torch-geometric',
        'pyg-lib', 'torch-scatter', 'torch-sparse',
        'torch-cluster', 'torch-spline-conv'
    ]

    for package in pyg_packages:
        pyg_result = subprocess.run([
            sys.executable, '-m', 'pip', 'install', package
        ], capture_output=True, text=True)

        if pyg_result.returncode == 0:
            print(f"✅ {package} installed")
        else:
            print(f"⚠️ {package} installation issue: {pyg_result.stderr[:100]}...")

# Install from requirements.txt if available
if os.path.exists('requirements.txt'):
    print("\n📋 Found requirements.txt. Installing dependencies...")
    result = subprocess.run(
        [sys.executable, '-m', 'pip', 'install', '-r', 'requirements.txt'],
        capture_output=True,
        text=True
    )
    print("STDOUT:")
    print(result.stdout[-1000:])  # Show last 1000 chars
    if result.stderr:
        print("STDERR:")
        print(result.stderr[-1000:])  # Show last 1000 chars
    print(f"Installation completed with return code: {result.returncode}")
else:
    print("\n📦 requirements.txt not found. Installing common dependencies...")
    essential_packages = [
        'torch',
        'torch_geometric',
        'tensorboard',
        'multipledispatch',
        'statsmodels',
        'matplotlib',
        'numpy',
        'pandas'
    ]

    for package in essential_packages:
        print(f"Installing {package}...")
        result = subprocess.run(
            [sys.executable, '-m', 'pip', 'install', package],
            capture_output=True,
            text=True
        )
        if result.returncode == 0:
            print(f"✅ {package} installed successfully")
        else:
            print(f"❌ {package} installation failed: {result.stderr[:100]}...")

print("\n🎉 Dependency installation completed!")
# Out:
# 📦 Installing Python dependencies...
# 🔥 Installing PyTorch with CUDA support for Colab...
# ✅ PyTorch with CUDA installed successfully
# 📊 Installing PyTorch Geometric with CUDA support...
# ✅ torch-geometric installed
# ⚠️ pyg-lib installation issue: ERROR: Could not find a version that satisfies the requirement pyg-lib (from versions: none)
# ERROR: ...
# ⚠️ torch-scatter installation issue:   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#  ...
# ⚠️ torch-sparse installation issue:   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#  ...
# ⚠️ torch-cluster installation issue:   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#  ...
# ⚠️ torch-spline-conv installation issue:   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#  ...
#
# 📋 Found requirements.txt. Installing dependencies...
# STDOUT:
# (line 6)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric->-r requirements.txt (line 6)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric->-r requirements.txt (line 6)) (1.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric->-r requirements.txt (line 6)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric->-r requirements.txt (line 6)) (2025.8.3)
#
# Installation completed with return code: 0
#
# 🎉 Dependency installation completed!

# %% [markdown]
# ## 3. Verify Installation
#
# Check that all critical dependencies are properly installed and accessible.

# %%
# Check critical imports
required_packages = {
    'torch': 'PyTorch for deep learning',
    'torch_geometric': 'PyTorch Geometric for graph neural networks',
    'tensorboard': 'TensorBoard for logging',
    'multipledispatch': 'Multiple dispatch for Python',
    'statsmodels': 'Statistical models',
    'numpy': 'Numerical computing',
    'matplotlib': 'Plotting library'
}

print("🔍 Verifying package installations:\n")
for package, description in required_packages.items():
    try:
        module = __import__(package)
        # Try to get version if available
        version = getattr(module, '__version__', 'unknown')
        print(f"✅ {package:<20} v{version:<10} - {description}")
    except ImportError as e:
        print(f"❌ {package:<20} {'FAILED':<10} - {e}")

# Check PyTorch CUDA availability
try:
    import torch
    if torch.cuda.is_available():
        device_name = torch.cuda.get_device_name(0)
        print(f"\n🚀 CUDA Status: Available ({device_name})")
        print(f"   CUDA Version: {torch.version.cuda}")
        print(f"   PyTorch Version: {torch.__version__}")
    else:
        print(f"\n💻 CUDA Status: Not available (using CPU)")
        print(f"   PyTorch Version: {torch.__version__}")
except ImportError:
    print("\n❌ PyTorch not available")

# Check if main project files exist
print(f"\n📁 Checking project files:")
essential_files = ['main.py', 'requirements.txt', 'src/']
for file in essential_files:
    if os.path.exists(file):
        if os.path.isfile(file):
            size = os.path.getsize(file)
            print(f"✅ {file:<15} ({size:,} bytes)")
        else:
            items = len(os.listdir(file)) if os.path.isdir(file) else 0
            print(f"✅ {file:<15} ({items} items)")
    else:
        print(f"❌ {file:<15} (not found)")

# List current directory contents
print(f"\n📋 Current directory contents:")
items = sorted(os.listdir('.'))
for item in items[:15]:  # Show first 15 items
    if os.path.isfile(item):
        size = os.path.getsize(item)
        print(f"📄 {item:<25} ({size:,} bytes)")
    else:
        try:
            count = len(os.listdir(item))
            print(f"📁 {item}\<20 ({count} items)")
        except:
            print(f"📁 {item}/")

if len(items) > 15:
    print(f"... and {len(items) - 15} more items")

print("\n🎯 Installation verification completed!")
# Out:
# 🔍 Verifying package installations:
#
# ✅ torch                v2.6.0+cu118 - PyTorch for deep learning
# ✅ torch_geometric      v2.6.1      - PyTorch Geometric for graph neural networks
# ✅ tensorboard          v2.19.0     - TensorBoard for logging
# ✅ multipledispatch     v0.6.0      - Multiple dispatch for Python
# ✅ statsmodels          v0.14.5     - Statistical models
# ✅ numpy                v2.0.2      - Numerical computing
# ✅ matplotlib           v3.10.0     - Plotting library
#
# 🚀 CUDA Status: Available (Tesla T4)
#    CUDA Version: 11.8
#    PyTorch Version: 2.6.0+cu118
#
# 📁 Checking project files:
# ✅ main.py         (2,629 bytes)
# ✅ requirements.txt (85 bytes)
# ✅ src/            (8 items)
#
# 📋 Current directory contents:
# 📁 .git\<20 (13 items)
# 📁 .github\<20 (1 items)
# 📄 .gitignore                (406 bytes)
# 📁 .idea\<20 (5 items)
# 📁 .vscode\<20 (2 items)
# 📄 Asia.txt                  (290 bytes)
# 📄 Asia_Europe.txt           (525 bytes)
# 📄 CONFIGURATION_SYSTEM_SUMMARY.md (0 bytes)
# 📄 LOGGING_VERBOSITY_FIX.md  (2,507 bytes)
# 📄 NODE_FEATURES_USAGE_VERIFICATION.md (3,374 bytes)
# 📄 PPO_FIRST_EPOCH_FIX_SUMMARY.md (2,397 bytes)
# 📄 VALUE_COMPUTATION_VERIFICATION.md (7,748 bytes)
# 📁 analysis\<20 (1 items)
# 📄 analyze_tensorboard.py    (22,235 bytes)
# 📄 army_approach_comparison.py (0 bytes)
# ... and 55 more items
#
# 🎯 Installation verification completed!

# %% [markdown]
# ## 4. Set Up Environment Variables
#
# Configure any necessary environment variables or path settings for the project.

# %%
# Set up environment variables
print("⚙️ Setting up environment variables...")

# Environment variables for optimal performance
env_vars = {
    'PYTHONPATH': os.getcwd(),  # Add current directory to Python path
    'TF_ENABLE_ONEDNN_OPTS': '0',  # Disable oneDNN for consistent results
    'CUDA_LAUNCH_BLOCKING': '1',  # For better CUDA error reporting
    'TORCH_USE_CUDA_DSA': '1',  # Enhanced CUDA debugging
}

# Add GPU-specific settings if available
try:
    import torch
    if torch.cuda.is_available() and IN_COLAB:
        env_vars['CUDA_VISIBLE_DEVICES'] = '0'
        print("🚀 GPU-specific environment variables added")
except:
    pass

for var, value in env_vars.items():
    os.environ[var] = value
    print(f"✅ Set {var} = {value}")

print("\n📍 Environment setup complete!")
print(f"Current PYTHONPATH: {os.environ.get('PYTHONPATH', 'Not set')}")
print(f"Working directory: {os.getcwd()}")

# Verify Python can find the project modules
sys.path.insert(0, os.getcwd())
print(f"✅ Added current directory to Python path")
# Out:
# ⚙️ Setting up environment variables...
# ✅ Set PYTHONPATH = /content/pyWarlight
# ✅ Set TF_ENABLE_ONEDNN_OPTS = 0
# ✅ Set CUDA_LAUNCH_BLOCKING = 1
# ✅ Set TORCH_USE_CUDA_DSA = 1
#
# 📍 Environment setup complete!
# Current PYTHONPATH: /content/pyWarlight
# Working directory: /content/pyWarlight
# ✅ Added current directory to Python path

# %% [markdown]
# ## 5. Execute Main Command
#
# Run the main command with the specified configuration: `python main.py Attila.1 RLGNNAgent.2 -sim 1 -map World -config debug`

# %% [markdown]
# ## 6. Capture and Display Output
#
# Analyze the command output and display key information about the simulation results.

# %%
# Analyze the output
print("📊 === EXECUTION SUMMARY ===")
print(f"Return Code: {return_code}")
print(f"Execution Status: {'✅ SUCCESS' if return_code == 0 else '❌ FAILED'}")

if 'full_output' in locals() and full_output:
    # Extract key information from the output
    lines = full_output.split('\n')

    print(f"\n📈 === OUTPUT ANALYSIS ===")
    print(f"Total output lines: {len(lines)}")

    # Look for configuration messages
    config_lines = [line for line in lines if any(word in line.lower()
                   for word in ['configuration', 'config', 'applied', 'switching'])]
    if config_lines:
        print("\n📝 Configuration Messages:")
        for line in config_lines[:5]:  # Show first 5 config lines
            print(f"  {line}")

    # Look for training/model information
    training_lines = [line for line in lines if any(word in line.lower()
                     for word in ['training', 'model', 'epoch', 'loss', 'learning'])]
    if training_lines:
        print("\n🏗️ Model/Training Information:")
        for line in training_lines[:5]:  # Show first 5 training lines
            print(f"  {line}")

    # Look for game results
    result_lines = [line for line in lines if any(word in line.lower()
                   for word in ['won', 'result', 'winner', 'game', 'finished'])]
    if result_lines:
        print("\n🎮 Game Results:")
        for line in result_lines[-5:]:  # Show last 5 result lines
            print(f"  {line}")

    # Look for performance metrics
    perf_lines = [line for line in lines if any(word in line.lower()
                 for word in ['fps', 'time', 'duration', 'speed', 'performance'])]
    if perf_lines:
        print("\n⚡ Performance Metrics:")
        for line in perf_lines[-3:]:  # Show last 3 performance lines
            print(f"  {line}")

    # Look for errors or warnings (show only serious ones)
    error_lines = [line for line in lines if any(word in line.lower()
                  for word in ['error', 'exception', 'failed', 'critical'])]
    warning_lines = [line for line in lines if 'warning' in line.lower()]

    if error_lines:
        print("\n❌ Errors:")
        for line in error_lines[:5]:  # Show first 5 error lines
            print(f"  {line}")

    if warning_lines and len(warning_lines) <= 10:  # Only show if not too many
        print("\n⚠️ Warnings:")
        for line in warning_lines[:5]:  # Show first 5 warning lines
            print(f"  {line}")
    elif len(warning_lines) > 10:
        print(f"\n⚠️ Warnings: {len(warning_lines)} warnings detected (suppressed for brevity)")

    # Summary statistics
    error_count = len(error_lines)
    warning_count = len(warning_lines)
    print(f"\n📊 Summary: {error_count} errors, {warning_count} warnings")

else:
    print("\n❌ No output captured.")

print(f"\n🎯 === EXECUTION COMPLETE ===")
print("The PyWarlight RL simulation has finished running.")

if return_code == 0:
    print("\n✅ SUCCESS: The simulation completed successfully!")
    print("🎉 You can now analyze the results or run additional simulations.")
    if IN_COLAB:
        print("💡 Tip: Use TensorBoard to visualize training progress if logs were generated.")
else:
    print("\n❌ FAILED: The simulation encountered issues.")
    print("🔍 Check the output above for error messages and troubleshooting information.")
    print("\n🛠️ Common fixes:")
    print("   - Ensure all dependencies are properly installed")
    print("   - Check that project files were loaded correctly")
    print("   - Verify the configuration parameters are valid")

print(f"\n📁 Final working directory: {os.getcwd()}")
print(f"📄 Generated files: {[f for f in os.listdir('.') if f.endswith(('.log', '.pt', '.pkl', '.json'))]}")
# Out:
# 📊 === EXECUTION SUMMARY ===
# Return Code: 1
# Execution Status: ❌ FAILED
#
# 📈 === OUTPUT ANALYSIS ===
# Total output lines: 18
#
# ⚡ Performance Metrics:
#   2025-08-11 12:56:57.354557: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
#
# ❌ Errors:
#   2025-08-11 12:56:57.354557: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
#   ImportError: cannot import name 'override' from 'typing' (/usr/lib/python3.11/typing.py)
#
# ⚠️ Warnings:
#   WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
#
# 📊 Summary: 2 errors, 1 warnings
#
# 🎯 === EXECUTION COMPLETE ===
# The PyWarlight RL simulation has finished running.
#
# ❌ FAILED: The simulation encountered issues.
# 🔍 Check the output above for error messages and troubleshooting information.
#
# 🛠️ Common fixes:
#    - Ensure all dependencies are properly installed
#    - Check that project files were loaded correctly
#    - Verify the configuration parameters are valid
#
# 📁 Final working directory: /content/pyWarlight
# 📄 Generated files: []

# %%
# Prepare the command
import sys, os
command = [
    sys.executable,  # Use the same Python interpreter as the notebook
    'main.py',
    'Attila.1',
    'RLGNNAgent.2',
    '-sim', '10000',
    '-map', 'world',
    '-config', 'residual_percentage'
]

print(f"🎮 Executing command: {' '.join(command)}")
print(f"📍 Working directory: {os.getcwd()}")
print(f"🐍 Python executable: {sys.executable}")
print("=" * 80)

# Verify main.py exists before running
if not os.path.exists('main.py'):
    print("❌ Error: main.py not found in current directory!")
    print(f"Current directory: {os.getcwd()}")
    print(f"Files available: {[f for f in os.listdir('.') if f.endswith('.py')]}")
    print("Please ensure the project files are properly loaded.")
else:
    # Execute the command
    try:
        # Run the command and capture output
        process = subprocess.Popen(
            command,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
            bufsize=1,
            universal_newlines=True,
            cwd=os.getcwd()  # Explicitly set working directory
        )

        # Stream output in real-time
        output_lines = []
        for line in process.stdout:
            line_clean = line.rstrip()
            print(line_clean)
            output_lines.append(line_clean)

        # Wait for process to complete
        return_code = process.wait()

        print("=" * 80)
        print(f"🏁 Command completed with return code: {return_code}")

        # Store output for later analysis
        full_output = '\n'.join(output_lines)

        if return_code == 0:
            print("✅ Simulation completed successfully!")
        else:
            print("❌ Simulation failed - check output above for errors")

    except Exception as e:
        print(f"❌ Error executing command: {e}")
        return_code = -1
        full_output = ""
# Out:
# Streaming output truncated to the last 5000 lines.
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4430
# Gradient CV: 0.8103
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.3358
# Gradient CV: 0.6513
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.8149
# Gradient CV: 0.6183
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4270
# Gradient CV: 0.6847
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3888
# Gradient CV: 0.7813WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 581: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 582
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 582: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 583
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 583: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 584
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 584: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 585
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 585: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 586
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 586: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 587
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 587: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 588
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 588: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 589
#
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8770
# Gradient CV: 0.8296
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.1004
# Gradient CV: 0.8153
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 8.3399
# Gradient CV: 1.2586
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4536
# Gradient CV: 1.2446
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.5643
# Gradient CV: 1.0714
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4914
# Gradient CV: 1.0673
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.5841
# Gradient CV: 1.0566
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7145
# Gradient CV: 1.1829
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4683
# Gradient CV: 1.1791
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5194
# Gradient CV: 1.1672
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6450
# Gradient CV: 1.1869
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.1148
# Gradient CV: 1.1410
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.3111
# Gradient CV: 0.8360
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4306
# Gradient CV: 0.8387
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4532
# Gradient CV: 0.8655
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4625
# Gradient CV: 0.8695
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.0362
# Gradient CV: 0.8398
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4465
# Gradient CV: 0.8758
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6756
# Gradient CV: 0.8477
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6807
# Gradient CV: 0.8266
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4649
# Gradient CV: 0.8511
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.5037
# Gradient CV: 0.7556
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6381
# Gradient CV: 0.8068
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.2073
# Gradient CV: 0.7299
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.8767
# Gradient CV: 0.7328
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3646
# Gradient CV: 0.7461
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.0025
# Gradient CV: 0.7911
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4045
# Gradient CV: 0.7965
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8127
# Gradient CV: 0.7824
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3446
# Gradient CV: 0.8231
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4702
# Gradient CV: 0.8225
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.9372
# Gradient CV: 0.8153
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.2847
# Gradient CV: 0.7593
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.0488
# Gradient CV: 0.7570
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4422
# Gradient CV: 0.8475
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6534
# Gradient CV: 0.8113
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.8487
# Gradient CV: 0.8001
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9781
# Gradient CV: 0.7382
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9003
# Gradient CV: 0.7301
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.3803
# Gradient CV: 0.6369
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7983WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 589: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 590
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 590: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 591
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 591: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 592
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 592: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 593
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 593: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 594
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 594: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 595
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 595: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 596
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 596: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 597
# WARNING:root:No winning player
# WARNING:root:No winning player
#
# Gradient CV: 0.6018
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.3083
# Gradient CV: 0.6062
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6240
# Gradient CV: 0.6597
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.7750
# Gradient CV: 0.6390
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9608
# Gradient CV: 0.5861
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.5496
# Gradient CV: 0.5247
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.2467
# Gradient CV: 0.5580
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8458
# Gradient CV: 0.5691
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7192
# Gradient CV: 0.5856
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9370
# Gradient CV: 0.6145
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.2344
# Gradient CV: 0.5814
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.9675
# Gradient CV: 0.6062
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6399
# Gradient CV: 0.6045
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4502
# Gradient CV: 0.6825
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9047
# Gradient CV: 0.6873
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6416
# Gradient CV: 0.7529
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.0581
# Gradient CV: 0.6522
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.1631
# Gradient CV: 0.6290
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8166
# Gradient CV: 0.6192
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.5042
# Gradient CV: 0.5915
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.0559
# Gradient CV: 0.6018
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.1908
# Gradient CV: 0.4968
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4488
# Gradient CV: 0.5226
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3624
# Gradient CV: 0.5362
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4726
# Gradient CV: 0.5845
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4895
# Gradient CV: 0.6042
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.2035
# Gradient CV: 0.6183
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5256
# Gradient CV: 0.6758
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.2423
# Gradient CV: 0.7555
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.9650
# Gradient CV: 0.8507
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.1599
# Gradient CV: 0.8428
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.5674
# Gradient CV: 0.8582
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.9361
# Gradient CV: 0.7564
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.7097
# Gradient CV: 0.6597
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.6036
# Gradient CV: 0.5672
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.2615
# Gradient CV: 0.5027
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.8097
# Gradient CV: 0.5088
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.1305
# Gradient CV: 0.4550
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6926
# Gradient CV: 0.4023
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8326
# Gradient CV: 0.4327
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.1387
# Gradient CV: 0.4341
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too randomWARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 597: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 598
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 598: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 599
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 599: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 600
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 600: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:None = 0 (0.00%)
# INFO:root:,
# INFO:root:None = 0 (0.00%)
# INFO:root:None took 7.928113057769159e-05 ms/move
# INFO:root:,
# INFO:root:None took 0.0031056641407912703 ms/move
# INFO:root:
# INFO:root:starting game 601
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 601: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 602
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 602: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 603
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 603: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 604
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 604: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 605
# WARNING:root:No winning player
# WARNING:root:No winning player
#
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.7422
# Gradient CV: 0.4434
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4028
# Gradient CV: 0.5434
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 4.6029
# Gradient CV: 0.7023
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6559
# Gradient CV: 0.7913
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.8079
# Gradient CV: 0.7634
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.7233
# Gradient CV: 0.7667
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.3705
# Gradient CV: 0.7176
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7123
# Gradient CV: 0.7159
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5644
# Gradient CV: 0.7402
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7807
# Gradient CV: 0.7686
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.0349
# Gradient CV: 0.7722
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.8219
# Gradient CV: 0.6762
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.5172
# Gradient CV: 0.6168
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4373
# Gradient CV: 0.6389
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9798
# Gradient CV: 0.6837
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.9572
# Gradient CV: 0.7162
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.5934
# Gradient CV: 0.7412
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.1155
# Gradient CV: 0.6563
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6682
# Gradient CV: 0.6474
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8332
# Gradient CV: 0.6432
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.2047
# Gradient CV: 0.6483
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.7588
# Gradient CV: 0.6454
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.4901
# Gradient CV: 0.6217
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4795
# Gradient CV: 0.6179
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.8703
# Gradient CV: 0.5492
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 4.7880
# Gradient CV: 0.5836
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7954
# Gradient CV: 0.6319
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4349
# Gradient CV: 0.7498
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4231
# Gradient CV: 0.7707
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.1439
# Gradient CV: 0.7487
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.1614
# Gradient CV: 0.7998
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7806
# Gradient CV: 0.8865
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4772
# Gradient CV: 1.0062
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5081
# Gradient CV: 1.0027
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3281
# Gradient CV: 1.1681
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.5441
# Gradient CV: 0.5054
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.5402
# Gradient CV: 0.5397
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.5891
# Gradient CV: 0.5055
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.8909
# Gradient CV: 0.4737
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5430
# Gradient CV: 0.5255
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 4.5025
# Gradient CV: 0.8587
# Suggested epochs: 1 (healthy but unstable gradients (1-20))WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 605: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 606
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 606: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 607
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 607: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 608
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 608: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 609
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 609: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 610
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 610: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 611
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 611: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 612
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 612: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 613
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 613: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 614
#
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8301
# Gradient CV: 0.8539
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.2615
# Gradient CV: 0.7465
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4906
# Gradient CV: 0.7483
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5303
# Gradient CV: 0.7261
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.7685
# Gradient CV: 0.7341
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6990
# Gradient CV: 0.7935
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6883
# Gradient CV: 0.8589
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.7670
# Gradient CV: 0.8644
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9953
# Gradient CV: 0.8236
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.5280
# Gradient CV: 0.7138
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9864
# Gradient CV: 0.7005
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.1326
# Gradient CV: 0.7356
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4317
# Gradient CV: 0.7427
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5553
# Gradient CV: 0.7398
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.3325
# Gradient CV: 0.5823
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 6.8292
# Gradient CV: 0.9882
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7583
# Gradient CV: 0.9821
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.2870
# Gradient CV: 1.1036
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4242
# Gradient CV: 1.1600
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.9715
# Gradient CV: 1.1446
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.0711
# Gradient CV: 1.0686
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6649
# Gradient CV: 1.1095
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3390
# Gradient CV: 1.1192
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7749
# Gradient CV: 1.0982
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.0228
# Gradient CV: 1.0741
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.2588
# Gradient CV: 0.7966
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3706
# Gradient CV: 0.8430
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5540
# Gradient CV: 0.8078
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8185
# Gradient CV: 0.7632
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.3963
# Gradient CV: 0.7274
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6577
# Gradient CV: 0.7912
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7685
# Gradient CV: 0.7796
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4348
# Gradient CV: 0.7656
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7139
# Gradient CV: 0.7722
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.6761
# Gradient CV: 0.7264
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5203
# Gradient CV: 0.7938
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.0863
# Gradient CV: 0.7045
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.3769
# Gradient CV: 0.6384
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4240
# Gradient CV: 0.6837
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.2878
# Gradient CV: 0.6772
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 7.0482
# Gradient CV: 1.0410
# Suggested epochs: 1 (healthy but unstable gradients (1-20))WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 614: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 615
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 615: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 616
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 616: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 617
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 617: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 618
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 618: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 619
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 619: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 620
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 620: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 621
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 621: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 622
#
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.0654
# Gradient CV: 0.9554
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.0177
# Gradient CV: 0.9082
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5480
# Gradient CV: 0.9219
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 4.2220
# Gradient CV: 0.9073
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8334
# Gradient CV: 0.8834
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4390
# Gradient CV: 0.9901
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.6566
# Gradient CV: 0.9730
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4606
# Gradient CV: 0.9699
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.2703
# Gradient CV: 0.9706
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.2246
# Gradient CV: 0.7271
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.2646
# Gradient CV: 0.7623
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9758
# Gradient CV: 0.7656
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.0869
# Gradient CV: 0.7186
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.6347
# Gradient CV: 0.6035
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 7.8494
# Gradient CV: 0.9506
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6781
# Gradient CV: 0.9318
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.4308
# Gradient CV: 0.9447
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8959
# Gradient CV: 0.9117
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ...
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.8734
# Gradient CV: 0.5416
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7631
# Gradient CV: 0.4783
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5319
# Gradient CV: 0.5160
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.6251
# Gradient CV: 0.4983
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7606
# Gradient CV: 0.5370
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.2947
# Gradient CV: 0.6186
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.2909
# Gradient CV: 0.5811
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9722
# Gradient CV: 0.5752
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6101
# Gradient CV: 0.6267
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4169
# Gradient CV: 0.7257
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.4192
# Gradient CV: 0.6989
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9057
# Gradient CV: 0.6856
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.6029
# Gradient CV: 0.6087
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5849
# Gradient CV: 0.6799
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.9311
# Gradient CV: 0.6642
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.7612
# Gradient CV: 0.6000
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.5404
# Gradient CV: 0.5922
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3556
# Gradient CV: 0.6602WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 687: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 688
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 688: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 689
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 689: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 690
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 690: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 691
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 691: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 692
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 692: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 693
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 693: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 694
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 694: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 695
#
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8685
# Gradient CV: 0.6337
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5284
# Gradient CV: 0.6192
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.7294
# Gradient CV: 0.5869
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.3591
# Gradient CV: 0.6604
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3191
# Gradient CV: 0.7667
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.9580
# Gradient CV: 0.6841
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.2479
# Gradient CV: 0.7585
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.5036
# Gradient CV: 0.7490
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8409
# Gradient CV: 0.7965
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.1108
# Gradient CV: 0.7193
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3946
# Gradient CV: 0.7711
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.2991
# Gradient CV: 0.8005
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.1044
# Gradient CV: 0.8183
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.4091
# Gradient CV: 0.8822
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.5267
# Gradient CV: 0.7705
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.0186
# Gradient CV: 0.8079
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.0728
# Gradient CV: 0.7144
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.5925
# Gradient CV: 0.8036
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7817
# Gradient CV: 0.8093
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7741
# Gradient CV: 0.8392
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.3215
# Gradient CV: 0.7529
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8213
# Gradient CV: 0.6954
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.7603
# Gradient CV: 0.6747
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.6598
# Gradient CV: 0.5810
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.8435
# Gradient CV: 0.6243
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6749
# Gradient CV: 0.6549
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.3434
# Gradient CV: 0.7284
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.0976
# Gradient CV: 0.5914
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.5846
# Gradient CV: 0.6130
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7042
# Gradient CV: 0.6203
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.1574
# Gradient CV: 0.6277
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.6046
# Gradient CV: 0.6510
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.9255
# Gradient CV: 0.5555
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 2.6069
# Gradient CV: 0.6371
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.7049
# Gradient CV: 0.6001
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.3129
# Gradient CV: 0.5521
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 0.7714
# Gradient CV: 0.4995
# Suggested epochs: 1 (small unstable gradients (<1))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 3.5414
# Gradient CV: 0.6208
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# running new game
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.3226
# Gradient CV: 0.5615
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too random
#
# === ADAPTIVE EPOCHS ===
# Gradient norm: 1.3514
# Gradient CV: 0.5128
# Suggested epochs: 1 (healthy but unstable gradients (1-20))
# Actual epochs: 1
# ⚠️  Very high army entropy - policy may be too randomWARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 695: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 696
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 696: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 697
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 697: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 698
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 698: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 699
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 699: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 700
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 700: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:None = 0 (0.00%)
# INFO:root:,
# INFO:root:None = 0 (0.00%)
# INFO:root:None took 7.935173613140427e-05 ms/move
# INFO:root:,
# INFO:root:None took 0.003070814631052803 ms/move
# INFO:root:
# INFO:root:starting game 701
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 701: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 702
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# WARNING:root:No winning player
# INFO:root:seed 702: AgentConfig(init='internal: RLGNNAgent.2', name='2', extra_armies=0) won in 150 rounds
# INFO:root:
# INFO:root:starting game 703

# %%
from google.colab import drive
drive.mount('/content/drive')
